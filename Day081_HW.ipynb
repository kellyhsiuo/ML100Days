# %% [markdown]
# ## Work
# 1. 請比較使用 l1, l1_l2 及不同比例下的訓練結果

# %%
import os
import keras
import itertools
# Disable GPU
os.environ["CUDA_VISIBLE_DEVICES"] = ""

# %%
train, test = keras.datasets.cifar10.load_data()

# %%
## 資料前處理
def preproc_x(x, flatten=True):
    x = x / 255.
    if flatten:
        x = x.reshape((len(x), -1))
    return x

def preproc_y(y, num_classes=10):
    if y.shape[-1] == 1:
        y = keras.utils.to_categorical(y, num_classes)
    return y

# %%
x_train, y_train = train
x_test, y_test = test

# Preproc the inputs
x_train = preproc_x(x_train)
x_test = preproc_x(x_test)

# Preprc the outputs
y_train = preproc_y(y_train)
y_test = preproc_y(y_test)

# %%
from keras.regularizers import l1, l2, l1_l2
# def build_mlp(input_shape, output_units=10, num_neurons=[512, 256, 128], l1_ratio=0.0, l2_ratio=0.0):
#     input_layer = keras.layers.Input(input_shape)
    
#     for i, n_units in enumerate(num_neurons):
#         if i == 0:
#             x = keras.layers.Dense(units=n_units, 
#                                    activation="relu", 
#                                    name="hidden_layer"+str(i+1), 
#                                    kernel_regularizer=l1_l2(l1=l1_ratio, l2=l2_ratio))(input_layer)
#         else:
#             x = keras.layers.Dense(units=n_units, 
#                                    activation="relu", 
#                                    name="hidden_layer"+str(i+1),
#                                    kernel_regularizer=l1_l2(l1=l1_ratio, l2=l2_ratio))(x)
    
#     out = keras.layers.Dense(units=output_units, activation="softmax", name="output")(x)
    
#     model = keras.models.Model(inputs=[input_layer], outputs=[out])
#     return model

def build_mlp(input_shape, output_units=10, num_neurons=[512,256,128], l1_ratio=0.0, l2_ratio=0.0):
    input_layer = keras.layers.Input(input_shape)
    
    for i , n_units in enumerate(num_neurons):
        if i == 0:
            x = keras.layers.Dense(units=n_units,
                                  activation="relu",
                                  name="hidden_layer"+str(i+1),
                                  kernel_regularizer=l1_l2(l1=l1_ratio, l2=l2_ratio))(input_layer)
        else:
            x = keras.layers.Dense(units=n_units,
                                  activation="relu",
                                  kernel_regularizer=l1_l2(l1=l1_ratio, l2=l2_ratio))(x)
    
    out = keras.layers.Dense(units=output_units, activation="softmax", name="output")(x)
    model = keras.models.Model(inputs=[input_layer], outputs=[out])
    
    return model

# %%
"""Code Here
設定超參數
"""
LEARNING_RATE = 1e-3
EPOCHS = 10
BATCH_SIZE = 256
MOMENTUM = 0.95
L1_EXP = [1e-2, 1e-4, 1e-8, 1e-12, 0.0]
L2_EXP = [1e-2, 1e-4, 1e-8, 1e-12, 0.0]

# %%
results = {}
"""Code Here
撰寫你的訓練流程並將結果用 dictionary 紀錄
"""
# for l1r, l2r in itertools.product(L1_EXP, L2_EXP):
#     keras.backend.clear_session() # 把舊的 Graph 清掉
#     print("Experiment with L1 = %.6f, L2 = %.6f" % (l1r, l2r))
#     model = build_mlp(input_shape=x_train.shape[1:], l1_ratio=l1r, l2_ratio=l2r)
#     model.summary()
#     optimizer = keras.optimizers.SGD(lr=LEARNING_RATE, nesterov=True, momentum=MOMENTUM)
#     model.compile(loss="categorical_crossentropy", metrics=["accuracy"], optimizer=optimizer)

#     model.fit(x_train, y_train, 
#               epochs=EPOCHS, 
#               batch_size=BATCH_SIZE, 
#               validation_data=(x_test, y_test), 
#               shuffle=True)
    
#     # Collect results
#     train_loss = model.history.history["loss"]
#     valid_loss = model.history.history["val_loss"]
#     train_acc = model.history.history["acc"]
#     valid_acc = model.history.history["val_acc"]
    
#     exp_name_tag = "exp-l1-%s-l2-%s" % (str(l1r), str(l2r))
#     results[exp_name_tag] = {'train-loss': train_loss,
#                              'valid-loss': valid_loss,
#                              'train-acc': train_acc,
#                              'valid-acc': valid_acc}
    
for l1r, l2r in itertools.product(L1_EXP, L2_EXP):
    keras.backend.clear_session()
    print("Experiment with L1 = %.6f, L2 = %.6f" % (l1r, l2r))
    model = build_mlp(input_shape=x_train.shape[1:], l1_ratio=l1r, l2_ratio=l2r)
    model.summary()
    optimizer = keras.optimizers.SGD(lr=LEARNING_RATE, nesterov=True, momentum=MOMENTUM)
    model.compile(loss="categorical_crossentropy", metrics=["accuracy"], optimizer=optimizer)
    
    model.fit(x_train, y_train,
             epochs=EPOCHS,
             batch_size=BATCH_SIZE,
             validation_data=(x_test, y_test),
             shuffle=True)
    train_loss = model.history.history["loss"]
    valid_loss = model.history.history["val_loss"]
    train_acc = model.history.history["accuracy"]
    valid_acc = model.history.history["val_accuracy"]
    
    exp_name_tag = "exp-l1-%s-l2-%s" % (str(l1r), str(l2r))
    results[exp_name_tag] = {'train_loss':train_loss,
                            'valid_loss':valid_loss,
                            'train_acc':train_acc,
                            'valid_acc':valid_acc}
# Out:
# Experiment with L1 = 0.010000, L2 = 0.010000
# Model: "model_1"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_1 (InputLayer)         (None, 3072)              0
# _________________________________________________________________
# hidden_layer1 (Dense)        (None, 512)               1573376
# _________________________________________________________________
# dense_1 (Dense)              (None, 256)               131328
# _________________________________________________________________
# dense_2 (Dense)              (None, 128)               32896
# _________________________________________________________________
# output (Dense)               (None, 10)                1290
# =================================================================
# Total params: 1,738,890
# Trainable params: 1,738,890
# Non-trainable params: 0
# _________________________________________________________________
# WARNING:tensorflow:From C:\Users\apply\AppData\Roaming\Python\Python36\site-packages\tensorflow\python\ops\math_ops.py:3066: to_int32 (from tensorflow.python.ops.math_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use tf.cast instead.
# Train on 50000 samples, validate on 10000 samples
# Epoch 1/10
# 50000/50000 [==============================] - 6s 115us/step - loss: 197.9291 - accuracy: 0.2319 - val_loss: 35.9418 - val_accuracy: 0.2502
# Epoch 2/10
# 50000/50000 [==============================] - 5s 90us/step - loss: 15.8906 - accuracy: 0.1104 - val_loss: 5.1098 - val_accuracy: 0.1000
# Epoch 3/10
# 50000/50000 [==============================] - 4s 88us/step - loss: 3.2039 - accuracy: 0.0972 - val_loss: 2.4715 - val_accuracy: 0.1000
# Epoch 4/10
# 50000/50000 [==============================] - 4s 85us/step - loss: 2.4632 - accuracy: 0.0969 - val_loss: 2.4625 - val_accuracy: 0.1000
# Epoch 5/10
# 50000/50000 [==============================] - 4s 85us/step - loss: 2.4624 - accuracy: 0.0984 - val_loss: 2.4625 - val_accuracy: 0.1000
# Epoch 6/10
# 50000/50000 [==============================] - 4s 85us/step - loss: 2.4624 - accuracy: 0.0981 - val_loss: 2.4625 - val_accuracy: 0.1000
# Epoch 7/10
# 50000/50000 [==============================] - 4s 84us/step - loss: 2.4623 - accuracy: 0.0978 - val_loss: 2.4624 - val_accuracy: 0.1000
# Epoch 8/10
# 50000/50000 [==============================] - 4s 83us/step - loss: 2.4623 - accuracy: 0.0977 - val_loss: 2.4622 - val_accuracy: 0.1000
# Epoch 9/10
# 50000/50000 [==============================] - 4s 83us/step - loss: 2.4623 - accuracy: 0.0964 - val_loss: 2.4623 - val_accuracy: 0.1000
# Epoch 10/10
# 50000/50000 [==============================] - 4s 82us/step - loss: 2.4622 - accuracy: 0.0961 - val_loss: 2.4622 - val_accuracy: 0.1000
# Experiment with L1 = 0.010000, L2 = 0.000100
# Model: "model_1"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_1 (InputLayer)         (None, 3072)              0
# _________________________________________________________________
# hidden_layer1 (Dense)        (None, 512)               1573376
# _________________________________________________________________
# dense_1 (Dense)              (None, 256)               131328
# _________________________________________________________________
# dense_2 (Dense)              (None, 128)               32896
# _________________________________________________________________
# output (Dense)               (None, 10)                1290
# =================================================================
# Total params: 1,738,890
# Trainable params: 1,738,890
# Non-trainable params: 0
# _________________________________________________________________
# Train on 50000 samples, validate on 10000 samples
# Epoch 1/10
# 50000/50000 [==============================] - 5s 92us/step - loss: 198.8502 - accuracy: 0.2453 - val_loss: 41.2208 - val_accuracy: 0.2755
# Epoch 2/10
# 50000/50000 [==============================] - 4s 86us/step - loss: 19.1780 - accuracy: 0.1190 - val_loss: 7.3126 - val_accuracy: 0.1000
# Epoch 3/10
# 50000/50000 [==============================] - 4s 86us/step - loss: 4.1181 - accuracy: 0.0988 - val_loss: 2.6466 - val_accuracy: 0.1000
# Epoch 4/10
# 50000/50000 [==============================] - 4s 84us/step - loss: 2.4862 - accuracy: 0.0968 - val_loss: 2.4625 - val_accuracy: 0.1000
# Epoch 5/10
# 50000/50000 [==============================] - 4s 83us/step - loss: 2.4626 - accuracy: 0.0992 - val_loss: 2.4626 - val_accuracy: 0.1000
# Epoch 6/10
# 50000/50000 [==============================] - 4s 84us/step - loss: 2.4626 - accuracy: 0.0996 - val_loss: 2.4625 - val_accuracy: 0.1000
# Epoch 7/10
# 50000/50000 [==============================] - 4s 87us/step - loss: 2.4626 - accuracy: 0.0987 - val_loss: 2.4625 - val_accuracy: 0.1000
# Epoch 8/10
# 50000/50000 [==============================] - 4s 85us/step - loss: 2.4626 - accuracy: 0.0985 - val_loss: 2.4625 - val_accuracy: 0.1000
# Epoch 9/10
# 50000/50000 [==============================] - 4s 84us/step - loss: 2.4626 - accuracy: 0.0973 - val_loss: 2.4625 - val_accuracy: 0.1000
# Epoch 10/10
# 50000/50000 [==============================] - 4s 83us/step - loss: 2.4626 - accuracy: 0.0986 - val_loss: 2.4625 - val_accuracy: 0.1000
# Experiment with L1 = 0.010000, L2 = 0.000000
# Model: "model_1"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_1 (InputLayer)         (None, 3072)              0
# _________________________________________________________________
# hidden_layer1 (Dense)        (None, 512)               1573376
# _________________________________________________________________
# dense_1 (Dense)              (None, 256)               131328
# _________________________________________________________________
# dense_2 (Dense)              (None, 128)               32896
# _________________________________________________________________
# output (Dense)               (None, 10)                1290
# =================================================================
# Total params: 1,738,890
# Trainable params: 1,738,890
# Non-trainable params: 0
# _________________________________________________________________
# Train on 50000 samples, validate on 10000 samples
# Epoch 1/10
# 50000/50000 [==============================] - 5s 92us/step - loss: 198.7638 - accuracy: 0.2274 - val_loss: 41.2085 - val_accuracy: 0.2577
# Epoch 2/10
# 50000/50000 [==============================] - 4s 83us/step - loss: 19.1544 - accuracy: 0.1204 - val_loss: 7.2973 - val_accuracy: 0.1000
# Epoch 3/10
# 50000/50000 [==============================] - 4s 83us/step - loss: 4.1166 - accuracy: 0.1002 - val_loss: 2.6524 - val_accuracy: 0.1000
# Epoch 4/10
# 50000/50000 [==============================] - 4s 83us/step - loss: 2.4869 - accuracy: 0.0987 - val_loss: 2.4625 - val_accuracy: 0.1000
# Epoch 5/10
# 50000/50000 [==============================] - 4s 88us/step - loss: 2.4626 - accuracy: 0.0984 - val_loss: 2.4625 - val_accuracy: 0.1000
# Epoch 6/10
# 50000/50000 [==============================] - 5s 94us/step - loss: 2.4626 - accuracy: 0.0969 - val_loss: 2.4625 - val_accuracy: 0.1000

# %%
import matplotlib.pyplot as plt
# %matplotlib inline
"""Code Here
將結果繪出
"""
import matplotlib.cm as mplcm
import matplotlib.colors as colors
NUM_COLORS = 25

cm = plt.get_cmap('gist_rainbow')
cNorm  = colors.Normalize(vmin=0, vmax=NUM_COLORS-1)
scalarMap = mplcm.ScalarMappable(norm=cNorm, cmap=cm)
color_bar = [scalarMap.to_rgba(i) for i in range(NUM_COLORS)]

plt.figure(figsize=(8,6))
for i, cond in enumerate(results.keys()):
    plt.plot(range(len(results[cond]['train-loss'])),results[cond]['train-loss'], '-', label=cond, color=color_bar[i])
    plt.plot(range(len(results[cond]['valid-loss'])),results[cond]['valid-loss'], '--', label=cond, color=color_bar[i])
plt.title("Loss")
plt.ylim([0, 5])
plt.legend()
plt.show()

plt.figure(figsize=(8,6))
for i, cond in enumerate(results.keys()):
    plt.plot(range(len(results[cond]['train-acc'])),results[cond]['train-acc'], '-', label=cond, color=color_bar[i])
    plt.plot(range(len(results[cond]['valid-acc'])),results[cond]['valid-acc'], '--', label=cond, color=color_bar[i])
plt.title("Accuracy")
plt.legend()
plt.show()
